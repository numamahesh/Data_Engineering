# %%
from pyspark.sql import *



if __name__ == "__main__":
    spark = SparkSession \
        .builder \
        .appName("Stores") \
        .master("local[2]") \
        .getOrCreate()
    sc = spark.sparkContext
    sc.setLogLevel("ALL")
path=r"C:\Users\dnaga\Documents\Work_Umamahesh\Data_Engineering\resources\Superstore_orders.csv"
df = spark.read.option("header",True).options(delimiter=',')\
    .csv(path)
#df.show()
#df2=df["customer_name"]
#df2=df.columns
df2=df.select("customer_name").show(truncate=False)
# Out:
# +------------------+
# |customer_name     |
# +------------------+
# |Claire Gute       |
# |Claire Gute       |
# |Darrin Van Huff   |
# |Sean O'Donnell    |
# |Sean O'Donnell    |
# |Brosina Hoffman   |
# |Brosina Hoffman   |
# |Brosina Hoffman   |
# |Brosina Hoffman   |
# |Brosina Hoffman   |
# |Brosina Hoffman   |
# |Brosina Hoffman   |
# |Andrew Allen      |
# |Irene Maddox      |
# |Harold Pawlan     |
# |Harold Pawlan     |
# |Pete Kriz         |
# |Alejandro Grove   |
# |Zuschuss Donatelli|
# |Zuschuss Donatelli|
# +------------------+
# only showing top 20 rows

# %%
import pandas as pd
import regex
path=r"C:\Users\dnaga\Documents\Work_Umamahesh\Data_Engineering\resources\Superstore_orders.csv"
df = pd.read_csv(path)
#df.head()
df2=df.query('customer_name.str.contains("Claire Gute")')
df2
# Out:
#       row_id        order_id  order_date   ship_date     ship_mode  \
# 0          1  CA-2020-152156   11/8/2020  11/11/2020  Second Class
# 1          2  CA-2020-152156   11/8/2020  11/11/2020  Second Class
# 5491    5492  CA-2021-164098   1/26/2021   1/27/2021   First Class
# 6877    6878  US-2019-123918  10/15/2019  10/15/2019      Same Day
# 6878    6879  US-2019-123918  10/15/2019  10/15/2019      Same Day
#
#      customer_id customer_name   segment        country       city  ...  \
# 0       CG-12520   Claire Gute  Consumer  United States  Henderson  ...
# 1       CG-12520   Claire Gute  Consumer  United States  Henderson  ...
# 5491    CG-12520   Claire Gute  Consumer  United States    Houston  ...
# 6877    CG-12520   Claire Gute  Consumer  United States     Dallas  ...
# 6878    CG-12520   Claire Gute  Consumer  United States     Dallas  ...
#
#      postal_code   region       product_id         category sub_category  \
# ...

# %%
df['order_date'] = pd.to_datetime(df['order_date'], format='%m/%d/%y', errors='coerce')
  
# Filter data between two dates
filtered_df = df.loc[(df['order_date'] >= '12/01/2020')
                     & (df['order_date'] < '12/31/2020-')]

filtered_df
# Out:
#       row_id        order_id order_date   ship_date       ship_mode  \
# 13        14  CA-2020-161389 2020-12-05  12/10/2020  Standard Class
# 21        22  CA-2020-137330 2020-12-09  12/13/2020  Standard Class
# 22        23  CA-2020-137330 2020-12-09  12/13/2020  Standard Class
# 35        36  CA-2020-117590 2020-12-08  12/10/2020     First Class
# 36        37  CA-2020-117590 2020-12-08  12/10/2020     First Class
# ...      ...             ...        ...         ...             ...
# 9975    9976  US-2020-103674 2020-12-06  12/10/2020  Standard Class
# 9976    9977  US-2020-103674 2020-12-06  12/10/2020  Standard Class
# 9977    9978  US-2020-103674 2020-12-06  12/10/2020  Standard Class
# 9978    9979  US-2020-103674 2020-12-06  12/10/2020  Standard Class
# 9979    9980  US-2020-103674 2020-12-06  12/10/2020  Standard Class
#
#      customer_id customer_name      segment        country         city  ...  \
# ...
